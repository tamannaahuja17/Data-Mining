# %% [markdown]
# Apply data pre-processing techniques such as standardization/normalization, transformation, aggregation, discretization/binarization, sampling etc. on any da

# %%
import pandas as pd
import numpy as np

# %%
data={'Age': np.random.randint( 30,70,100),'Income': np.random.randint(20000,100000,100)}
df=pd.DataFrame(data)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
std_data = pd.DataFrame(scaler.fit_transform(df),columns=['Age','Income'])
display(std_data)
std_data.describe()
# Out:
#          Age    Income
# 0  -1.336233 -0.100113
# 1   1.368692 -0.929850
# 2  -0.254263 -1.354497
# 3  -0.254263 -0.384232
# 4  -1.155905 -0.856769
# ..       ...       ...
# 95  0.286722 -1.492698
# 96 -0.795248 -0.561627
# 97  0.106394 -1.456484
# 98 -1.065741  1.507877
# 99 -1.336233  0.016653
#
# [100 rows x 2 columns]
#                 Age        Income
# count  1.000000e+02  1.000000e+02
# mean  -5.773160e-17 -3.257811e-17
# std    1.005038e+00  1.005038e+00
# min   -1.696890e+00 -1.565942e+00
# 25%   -9.079533e-01 -8.736307e-01
# 50%    1.063937e-01 -1.346331e-01
# 75%    8.277072e-01  9.415485e-01
# max    1.729349e+00  1.580427e+00

# %%
from sklearn.preprocessing import MinMaxScaler
min_max_scaler = MinMaxScaler()
normalized_data = pd.DataFrame(scaler.fit_transform(df),columns = ['Age','Income'])
display(normalized_data)
# Out:
#          Age    Income
# 0  -1.336233 -0.100113
# 1   1.368692 -0.929850
# 2  -0.254263 -1.354497
# 3  -0.254263 -0.384232
# 4  -1.155905 -0.856769
# ..       ...       ...
# 95  0.286722 -1.492698
# 96 -0.795248 -0.561627
# 97  0.106394 -1.456484
# 98 -1.065741  1.507877
# 99 -1.336233  0.016653
#
# [100 rows x 2 columns]

# %%
df_transformed = df.copy()
df_transformed['Income'] = np.log(df_transformed['Income'])
df_transformed
# Out:
#     Age     Income
# 0    44  10.304744
# 1    56  11.127880
# 2    63  10.272738
# 3    68  10.958984
# 4    34  10.369922
# ..  ...        ...
# 95   57  10.927538
# 96   64  10.319596
# 97   51  10.958340
# 98   48  10.761958
# 99   69  10.993681
#
# [100 rows x 2 columns]

# %%
df_aggregated= df.copy()
df_aggregated = df.groupby('Age').mean().reset_index()
df_aggregated.head()
# Out:
#    Age    Income
# 0   31  62455.75
# 1   32  69364.00
# 2   33  89088.00
# 3   34  57973.00
# 4   35  57375.50

# %%
bins = [19,30,50,np.inf]
labels = ['Young','Adult','Elderly']

df_descretized = df.copy()
df_descretized['Age group'] = pd.cut(df_descretized['Age'],bins = bins, labels = labels)
df_descretized.head()
# Out:
#    Age  Income Age group
# 0   34   57318     Adult
# 1   64   36995   Elderly
# 2   46   26594     Adult
# 3   46   50359     Adult
# 4   36   38785     Adult

# %%
from sklearn.preprocessing import Binarizer
threshold = 30
binarizer = Binarizer(threshold = threshold)
df_binarized = df.copy()
df_binarized = binarizer.fit_transform(df[['Age']])
df_binarized= pd.DataFrame(df_binarized, columns=['Binarized_Age'])
df_binarized=pd.concat([df,df_binarized],axis=1)
df_binarized.head()
# Out:
#    Age  Income  Binarized_Age
# 0   44   29874              1
# 1   56   68042              1
# 2   63   28933              1
# 3   68   57468              1
# 4   34   31886              1

# %%
sampled_data = df.sample(frac=0.1,random_state = 1)
sampled_data
# Out:
#     Age  Income
# 80   32   95816
# 84   53   86745
# 33   45   96248
# 81   48   80459
# 93   64   61910
# 17   69   88546
# 36   67   23893
# 82   53   54520
# 69   47   70219
# 65   57   29199
